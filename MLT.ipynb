# %% [markdown]
# <a href="https://colab.research.google.com/github/satyam0203-vide/MLT/blob/main/MLT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MEAN IMPUTATION

# %%
import pandas as pd
import numpy as np

# Create a sample DataFrame
df = pd.DataFrame([
    [3, 2, np.nan],
    [2, np.nan, 6],
    [np.nan, 8, 9]
])

# Impute missing values with the column mean
imputed_df = df.fillna(df.mean())

print(imputed_df)
# Out:
#      0    1    2
# 0  3.0  2.0  7.5
# 1  2.0  5.0  6.0
# 2  2.5  8.0  9.0

# %%
a = int(input("enter a number"))
b = int(input("enter a number"))
print(f"Largest is:{max(a,b)}")
# Out:
# enter a number3
# enter a number6
# Largest is:6
